# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import image

# %%
train  = np.loadtxt('plot_train.out')
valid  = np.loadtxt('plot_valid.out')

# %%
plt.figure()
plt.plot(train)
plt.plot(valid)
plt.imshow()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-2a9701aa0836> in <module>
#       2 plt.plot(train)
#       3 plt.plot(valid)
# ----> 4 plt.imshow()
#
# TypeError: imshow() missing 1 required positional argument: 'X'
